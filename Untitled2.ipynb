# %% [markdown]
# <a href="https://colab.research.google.com/github/I-Git5G/python-learnings/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-7b1a39e4-e2bb-4b5e-aa87-bc40946198f9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7b1a39e4-e2bb-4b5e-aa87-bc40946198f9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'Marketing Dashboard.xlsx - CookieTable.csv', 'sample_data']

# %%
df=pd.read_csv('Marketing Dashboard.xlsx - CookieTable.csv')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Cookie_id       999 non-null    int64
#  1   User_id         999 non-null    object
#  2   Cookie_message  999 non-null    object
#  3   Date            999 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 31.3+ KB
# None

# %%
df.head()
# Out:
#    Cookie_id User_id                        Cookie_message             Date
# 0          1  user_1  {Facebook,,Instagram,Twitter,Tiktok}  October 1, 2023
# 1          2  user_2  {Facebook,Adwords,Instagram,,Tiktok}  October 1, 2023
# 2          3  user_3                   {,Adwords,,,Tiktok}  October 1, 2023
# 3          4  user_4           {Facebook,,,Twitter,Tiktok}  October 1, 2023
# 4          5  user_5          {,,Instagram,Twitter,Tiktok}  October 1, 2023

# %%
import os
os.rename('Marketing Dashboard.xlsx - CookieTable.csv','cookies.csv')
df=pd.read_csv('cookies.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Cookie_id       999 non-null    int64
#  1   User_id         999 non-null    object
#  2   Cookie_message  999 non-null    object
#  3   Date            999 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 31.3+ KB

# %%
df.describe()
# Out:
#         Cookie_id
# count  999.000000
# mean   500.000000
# std    288.530761
# min      1.000000
# 25%    250.500000
# 50%    500.000000
# 75%    749.500000
# max    999.000000

# %%
print(df.isnull().sum())
# Out:
# Cookie_id         0
# User_id           0
# Cookie_message    0
# Date              0
# dtype: int64

# %%
df['Cookie_message'].unique()
# Out:
# array(['{Facebook,,Instagram,Twitter,Tiktok}',
#        '{Facebook,Adwords,Instagram,,Tiktok}', '{,Adwords,,,Tiktok}',
#        '{Facebook,,,Twitter,Tiktok}', '{,,Instagram,Twitter,Tiktok}',
#        '{Facebook,Adwords,Instagram,Twitter,Tiktok}',
#        '{,,Instagram,,Tiktok}', '{,Adwords,Instagram,,Tiktok}',
#        '{Facebook,,,,Tiktok}', '{Facebook,Adwords,,,Tiktok}',
#        '{,,,,Tiktok}', '{,,,Twitter,Tiktok}',
#        '{Facebook,Adwords,,Twitter,Tiktok}', '{,Adwords,,Twitter,Tiktok}',
#        '{Facebook,,Instagram,,Tiktok}',
#        '{,Adwords,Instagram,Twitter,Tiktok}'], dtype=object)

# %%
print(df.columns)
# Out:
# Index(['Cookie_id', 'User_id', 'Cookie_message', 'Date'], dtype='object')

# %%
print(df.shape)
print(df.columns)
# Out:
# (999, 4)
# Index(['Cookie_id', 'User_id', 'Cookie_message', 'Date'], dtype='object')

# %%
print(df.describe (include='all'))
# Out:
#          Cookie_id   User_id               Cookie_message             Date
# count   999.000000       999                          999              999
# unique         NaN       999                           16                7
# top            NaN  user_999  {Facebook,Adwords,,,Tiktok}  October 6, 2023
# freq           NaN         1                           76              205
# mean    500.000000       NaN                          NaN              NaN
# std     288.530761       NaN                          NaN              NaN
# min       1.000000       NaN                          NaN              NaN
# 25%     250.500000       NaN                          NaN              NaN
# 50%     500.000000       NaN                          NaN              NaN
# 75%     749.500000       NaN                          NaN              NaN
# max     999.000000       NaN                          NaN              NaN

# %%
print(df.dropna())
# Out:
#      Cookie_id   User_id                               Cookie_message  \
# 0            1    user_1         {Facebook,,Instagram,Twitter,Tiktok}
# 1            2    user_2         {Facebook,Adwords,Instagram,,Tiktok}
# 2            3    user_3                          {,Adwords,,,Tiktok}
# 3            4    user_4                  {Facebook,,,Twitter,Tiktok}
# 4            5    user_5                 {,,Instagram,Twitter,Tiktok}
# ..         ...       ...                                          ...
# 994        995  user_995  {Facebook,Adwords,Instagram,Twitter,Tiktok}
# 995        996  user_996                          {,,,Twitter,Tiktok}
# 996        997  user_997                          {,,,Twitter,Tiktok}
# 997        998  user_998                  {Facebook,,,Twitter,Tiktok}
# 998        999  user_999                          {,,,Twitter,Tiktok}
#
#                 Date
# 0    October 1, 2023
# 1    October 1, 2023
# 2    October 1, 2023
# 3    October 1, 2023
# ...

# %%
print(df.drop_duplicates())
# Out:
#      Cookie_id   User_id                               Cookie_message  \
# 0            1    user_1         {Facebook,,Instagram,Twitter,Tiktok}
# 1            2    user_2         {Facebook,Adwords,Instagram,,Tiktok}
# 2            3    user_3                          {,Adwords,,,Tiktok}
# 3            4    user_4                  {Facebook,,,Twitter,Tiktok}
# 4            5    user_5                 {,,Instagram,Twitter,Tiktok}
# ..         ...       ...                                          ...
# 994        995  user_995  {Facebook,Adwords,Instagram,Twitter,Tiktok}
# 995        996  user_996                          {,,,Twitter,Tiktok}
# 996        997  user_997                          {,,,Twitter,Tiktok}
# 997        998  user_998                  {Facebook,,,Twitter,Tiktok}
# 998        999  user_999                          {,,,Twitter,Tiktok}
#
#                 Date
# 0    October 1, 2023
# 1    October 1, 2023
# 2    October 1, 2023
# 3    October 1, 2023
# ...

# %%
df['channels'] = df['Cookie_message'].str.strip('{}') \
                                      .str.split(',') \
                                      .apply(lambda x: [ch for ch in x if ch.strip() != ''])

# %%
df[['User_id','channels']].head()
# Out:
#   User_id                                channels
# 0  user_1  [Facebook, Instagram, Twitter, Tiktok]
# 1  user_2  [Facebook, Adwords, Instagram, Tiktok]
# 2  user_3                       [Adwords, Tiktok]
# 3  user_4             [Facebook, Twitter, Tiktok]
# 4  user_5            [Instagram, Twitter, Tiktok]

# %%
df.to_csv('cleaned_cookie_table.csv',index=False)

# %%
from google.colab import files
files.download('cleaned_cookie_table.csv')
